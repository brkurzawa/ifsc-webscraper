# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np

# %%
boulder = pd.read_csv('boulder_results.csv')

# %%
for title in boulder['Competition Title'].unique():
    print(boulder[boulder['Competition Title'] == title][['Qualification', '1. Qualification', '2. Qualification']])
# Out:
#     Qualification 1. Qualification 2. Qualification
# 0          6T7z99              NaN              NaN
# 1         4T8z814              NaN              NaN
# 2          6T7z89              NaN              NaN
# 3          4T6z69              NaN              NaN
# 4         4T6z611              NaN              NaN
# 5          6T7z77              NaN              NaN
# 6         6T8z811              NaN              NaN
# 7          5T6z88              NaN              NaN
# 8        5T7z1213              NaN              NaN
# 9          7T7z97              NaN              NaN
# 10        7T7z109              NaN              NaN
# 11        6T6z107              NaN              NaN
# 12        5T7z611              NaN              NaN
# 13       5T5z1312              NaN              NaN
# 14       5T6z1210              NaN              NaN
# 15        6T7z910              NaN              NaN
# 16         6T7z88              NaN              NaN
# ...
